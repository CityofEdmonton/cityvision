# %%
# load library
import numpy as np
from PIL import Image
import cv2

# %%
# open video
cap = cv2.VideoCapture("../speed_tests/all_speed_test.mp4")

# get first frame and save as image
ret, frame = cap.read()
if ret:
    cv2.imwrite("first_frame.jpg", frame)
else:
    print("Error: Unable to read the first frame from the video.")
# Out:
# True
