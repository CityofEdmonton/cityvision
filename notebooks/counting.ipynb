# %%
import os
import numpy as np
from PIL import Image
import logging
from cityvision.models.main import yolo_counting_model, get_depth_map

# %%
# set up logging level to info
#logging.basicConfig(level=logging.INFO)

name = "yolo11l.pt"
config = {
    "camera_intrinsic": os.path.join("../configs/camera.yml"),
    "study_name": "test",
    "iou_threshold": 0.5,
    "confidence_threshold": 0.2,
    "direction_vector": {
        "EB": [[645, 290], [124, 180]],
        "WB": [[60, 195], [460, 420]],
    },
    "classes": {1: "bicycle", 2: "car", 3: "motorcycle", 5: "bus", 7: "truck"},
    "tracker_config": os.path.join("../configs/bytetrack.yml"),
    "report_path": os.path.join("../reports/"),
    "direction": ["EB", "WB"],
}
file_name = "SCU1VP_202503251031_001.mp4"
file_path = os.path.join("../assets/speed_tests/", file_name)

# %%
image = Image.open("../assets/test3.jpg")

# %%
model = yolo_counting_model(np.array(image), name, config)

# %%
model.run(file_path=file_path, file_name=file_name)
