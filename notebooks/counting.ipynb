# %%
import os
import numpy as np
from PIL import Image
import requests
import cv2
import logging
from cityvision.models.main import yolo_counting_model

# %%
# set up logging level to info
logging.basicConfig(level=logging.INFO)

name = "yolo11l.pt"
config = {'camera_intrinsic': os.path.join("../configs/camera.yml"),
          'study_name': 'test',
          'iou_threshold': 0.5,
          'confidence_threshold': 0.2,
          'direction_vector': {
              "EB": [[650, 320], [230, 70]],
              "WB": [[120, 70], [465, 430]],
          },
          'classes': {1: 'bicycle', 2: 'car', 3: 'motorcycle', 5: 'bus', 7: 'truck'},
          'tracker_config': os.path.join("../configs/bytetrack.yml"),
          'report_path': os.path.join("../reports/"),
          'direction': ['EB', 'WB']
        }
file_name = "SCU2VN_202410021845_020.mp4"
file_path = os.path.join("../assets/", file_name)

# %%
model = yolo_counting_model(name, config)
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.6 torch-2.0.1 CPU (Apple M1 Max)
# YOLO11l summary (fused): 190 layers, 25,340,992 parameters, 0 gradients, 86.9 GFLOPs
#
# PyTorch: starting from 'yolo11l.pt' with input shape (1, 3, 384, 576) BCHW and output shape(s) (1, 84, 4536) (49.0 MB)
#
# ONNX: starting export with onnx 1.16.2 opset 17...
# ================ Diagnostic Run torch.onnx.export version 2.0.1 ================
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: slimming with onnxslim 0.1.56...
# ONNX: export success ✅ 2.7s, saved as 'yolo11l.onnx' (96.9 MB)
#
# Export complete (3.2s)
# Results saved to /Users/S100AHBD/Desktop/CityVision/cityvision/notebooks
# Predict:         yolo predict task=detect model=yolo11l.onnx imgsz=384,576
# ...

# %%
model.run(file_path=file_path,file_name=file_name)
# Out:
# INFO:root:frame_width: 720
# INFO:root:frame_height: 480
# INFO:root:fps: 29
#   0%|          | 0/10792 [00:00<?, ?it/s]
# Loading yolo11l.onnx for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
#   0%|          | 33/10792 [00:05<29:52,  6.00it/s] INFO:root:Direction angle 1 for 1: 0.04463331191827767
# INFO:root:Direction angle 2 for 1: 2.916465158826605
#   0%|          | 34/10792 [00:06<29:37,  6.05it/s]INFO:root:Direction angle 1 for 1: 0.04086286399200638
# INFO:root:Direction angle 2 for 1: 2.912694710900334
#   0%|          | 35/10792 [00:06<29:50,  6.01it/s]INFO:root:Direction angle 1 for 1: 0.03616786393855715
# INFO:root:Direction angle 2 for 1: 2.9079997108468856
#   0%|          | 36/10792 [00:06<29:19,  6.11it/s]INFO:root:Direction angle 1 for 1: 0.03274198564537137
# INFO:root:Direction angle 2 for 1: 2.9045738325536954
#   0%|          | 37/10792 [00:06<29:24,  6.10it/s]INFO:root:Direction angle 1 for 1: 0.027115555511175483
# ...
